# %% [markdown]
# # E-Commerce Customer & Order Analysis

# %% [markdown]
# ### Notebook Structure

# %% [raw]
# 1. Project Introduction
# 2. Import Libraries
# 3. Load Dataset
# 4. Dataset Overview
# 5. Data Cleaning
# 6. Feature Engineering
# 7. Univariate Analysis
# 8. Bivariate Analysis
# 9. Correlation Analysis
# 10. Customer Segmentation Insights
# 11. Business Insights
# 12. Conclusion

# %% [markdown]
# ###  Project Goal

# %% [raw]
# Analyze customer purchase patterns and identify factors affecting order value and customer spending behavior.
#
# Key questions to answer:
#
# Which factors influence total order amount?
#
# Which customer segments spend the most?
#
# What is the relationship between income and purchase behavior?
#
# Which cities generate higher revenue?

# %% [markdown]
# ## Step 1 – Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %% [markdown]
# ## Step 2 – Load Dataset

# %%
df = pd.read_csv("E_Comm_dataset.csv")

df.head()
# Out:
#    user_ID            Name   Age  Gender   City Education_Level  \
# 0      1.0             NaN   NaN  Female    NaN        Graduate
# 1      2.0             NaN  26.0    Male  Delhi        Graduate
# 2      3.0  Anjali Agarwal  27.0  Female  Delhi            10th
# 3      4.0             NaN  20.0  Female    NaN        Graduate
# 4      5.0      Arjun Jain  28.0    Male  Delhi        Graduate
#
#    Monthly_Income Marrige_Status Date_of_order  Product_order_count  \
# 0         52860.0         Single    10-03-2023                  4.0
# 1             NaN         Single    14-04-2024                  1.0
# 2         25753.0         Single           NaN                  3.0
# 3             NaN       Divorced    27-02-2024                  4.0
# 4         35921.0            NaN    24-05-2024                  1.0
#
#    Order_Amount_INR  Wallet_Balance_INR  Total_Order_INR
# 0               NaN             21822.0          23134.0
# ...

# %%
df.shape
# Out:
# (250000, 13)

# %% [markdown]
# ## Step 3 – Dataset Overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   user_ID              247000 non-null  float64
#  1   Name                 55000 non-null   object
#  2   Age                  205000 non-null  float64
#  3   Gender               235000 non-null  object
#  4   City                 212500 non-null  object
#  5   Education_Level      225000 non-null  object
#  6   Monthly_Income       220000 non-null  float64
#  7   Marrige_Status       230000 non-null  object
#  8   Date_of_order        240000 non-null  object
#  9   Product_order_count  227500 non-null  float64
#  10  Order_Amount_INR     225000 non-null  float64
#  11  Wallet_Balance_INR   220000 non-null  float64
#  12  Total_Order_INR      246250 non-null  float64
# dtypes: float64(7), object(6)
# memory usage: 24.8+ MB

# %%
df.describe()
# Out:
#              user_ID            Age  Monthly_Income  Product_order_count  \
# count  247000.000000  205000.000000   220000.000000        227500.000000
# mean   124997.041255      29.030732    60638.916309             2.829327
# std     72167.275947       5.395641    43649.393097             1.736211
# min         1.000000      18.000000     8000.000000             0.000000
# 25%     62508.750000      25.000000    42698.000000             2.000000
# 50%    124994.500000      29.000000    55200.500000             3.000000
# 75%    187495.250000      33.000000    69183.000000             4.000000
# max    250000.000000      45.000000   855162.000000            14.000000
#
#        Order_Amount_INR  Wallet_Balance_INR  Total_Order_INR
# count     225000.000000       220000.000000    246250.000000
# mean        9386.270453        22394.636073     18795.052459
# std         7003.246199        14951.522049      8395.472472
# min           50.000000            0.000000       100.000000
# ...

# %%
df.isnull().sum()
# Out:
# user_ID                0
# Age                    0
# Gender                 0
# City                   0
# Education_Level        0
# Monthly_Income         0
# Marriage_Status        0
# Date_of_order          0
# Product_order_count    0
# Order_Amount_INR       0
# Wallet_Balance_INR     0
# Total_Order_INR        0
# avg_order_value        0
# income_group           0
# dtype: int64

# %% [markdown]
# ## Step 4 – Data Cleaning

# %%
df.rename(columns={"Marrige_Status":"Marriage_Status"}, inplace=True)  # Fix Column Names

# %%
df['Date_of_order'] = pd.to_datetime(df['Date_of_order'], dayfirst = True) # Convert Date Column

# %% [markdown]
# ### Handle Missing Values

# %%
# Numeric columns:

num_cols = [
'Age','Monthly_Income',
'Wallet_Balance_INR',
'Order_Amount_INR',
'Product_order_count'
]

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
# To check Column Is Causing the Error
for col in cat_cols:
    print(col)
    print(df[col].mode())
# Out:
# City
# 0    Unknown
# Name: City, dtype: object
# Gender
# 0    Unknown
# Name: Gender, dtype: object
# Marriage_Status
# 0    Unknown
# Name: Marriage_Status, dtype: object
# Education_Level
# 0    Unknown
# Name: Education_Level, dtype: object

# %%
cat_cols = ['City','Gender','Marriage_Status','Education_Level']

for col in cat_cols:
    if df[col].mode().empty:
        df[col] = df[col].fillna("Unknown")
    else:
        df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.columns
# Out:
# Index(['user_ID', 'Age', 'Gender', 'City', 'Education_Level', 'Monthly_Income',
#        'Marriage_Status', 'Date_of_order', 'Product_order_count',
#        'Order_Amount_INR', 'Wallet_Balance_INR', 'Total_Order_INR',
#        'avg_order_value'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# user_ID                0
# Age                    0
# Gender                 0
# City                   0
# Education_Level        0
# Monthly_Income         0
# Marriage_Status        0
# Date_of_order          0
# Product_order_count    0
# Order_Amount_INR       0
# Wallet_Balance_INR     0
# Total_Order_INR        0
# avg_order_value        0
# dtype: int64

# %%
df = df.dropna(subset=['user_ID'])

# %%
df = df.dropna(subset=['Date_of_order'])

# %%
df['Total_Order_INR'] = df['Order_Amount_INR'] * df['Product_order_count']

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])

# %% [markdown]
# ## Step 5 – Feature Engineering

# %%
# Average Order Value

#df['avg_order_value'] = df['Total_Order_INR'] / df['Product_order_count']

df['avg_order_value'] = np.where(
    df['Product_order_count'] > 0,
    df['Total_Order_INR'] / df['Product_order_count'],
    0
)

# %%
# Income Group

df['income_group'] = pd.qcut(
    df['Monthly_Income'],
    q=4,
    labels=['Low','Medium','High','Very High']
)

# %% [markdown]
# ## Step 6 – Univariate Analysis

# %%
# Age Distribution

plt.figure(figsize=(8,5))
sns.histplot(df['Age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %%
# Income Distribution

sns.histplot(df['Monthly_Income'], kde=True)
plt.title("Monthly Income Distribution")
# Out:
# Text(0.5, 1.0, 'Monthly Income Distribution')

# %%
# Order Amount Distribution

sns.boxplot(x=df['Order_Amount_INR'])
# Out:
# <Axes: xlabel='Order_Amount_INR'>

# %% [markdown]
# ## Step 7 – Bivariate Analysis

# %%
# Income vs Total Spending

sns.scatterplot(
    x='Monthly_Income',
    y='Total_Order_INR',
    data=df
)
# Out:
# <Axes: xlabel='Monthly_Income', ylabel='Total_Order_INR'>

# %%
# Gender vs Spending

sns.barplot(
    x='Gender',
    y='Total_Order_INR',
    data=df
)
# Out:
# <Axes: xlabel='Gender', ylabel='Total_Order_INR'>

# %%
# Education vs Spending

sns.barplot(
    x='Education_Level',
    y='Total_Order_INR',
    data=df
)
# Out:
# <Axes: xlabel='Education_Level', ylabel='Total_Order_INR'>

# %% [markdown]
# ## Step 8 – City Revenue Analysis

# %%
# Which cities generate highest revenue?

city_sales = df.groupby('City')['Total_Order_INR'].sum().sort_values(ascending=False)

city_sales.head(10).plot(kind='bar', figsize=(10,5))
plt.title("Top Cities by Revenue")
# Out:
# Text(0.5, 1.0, 'Top Cities by Revenue')

# %% [markdown]
# ## Step 9 – Income Group vs Spending

# %%
df.columns
# Out:
# Index(['user_ID', 'Age', 'Gender', 'City', 'Education_Level', 'Monthly_Income',
#        'Marriage_Status', 'Date_of_order', 'Product_order_count',
#        'Order_Amount_INR', 'Wallet_Balance_INR', 'Total_Order_INR',
#        'avg_order_value', 'income_group'],
#       dtype='object')

# %%
sns.boxplot(
    x='income_group',
    y='Total_Order_INR',
    data=df
)
# Out:
# <Axes: xlabel='income_group', ylabel='Total_Order_INR'>

# %% [markdown]
# ## Step 10 – Correlation Analysis

# %%
plt.figure(figsize=(10,6))

corr = df.corr(numeric_only=True)

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm"
)
# Out:
# <Axes: >

# %% [markdown]
# ## Step 11 – Customer Segmentation Insight

# %%
# High Value Customers

high_value = df[df['Total_Order_INR'] > df['Total_Order_INR'].quantile(0.75)]

# %%
high_value['City'].value_counts().head()
# Out:
# City
# Unknown    59273
# Name: count, dtype: int64

# %% [markdown]
# ## Step 12 – Business Insights

# %% [markdown]
# ## 1. Customer Age Distribution

# %%
plt.figure(figsize=(8,5))

sns.histplot(df['Age'], bins = 25, kde=True)

plt.title("Customer Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [raw]
# The age distribution of customers ranges from 18 to 45 years, with the majority concentrated between 25 and 35 years. The peak occurs around age 29, indicating that young adults form the largest segment of the customer base.

# %% [markdown]
# ## 2. Income Distribution

# %%
df['Monthly_Income'].describe()
# Out:
# count    237106.000000
# mean      59964.630566
# std       40948.885446
# min        8000.000000
# 25%       44574.000000
# 50%       55200.500000
# 75%       66717.000000
# max      855162.000000
# Name: Monthly_Income, dtype: float64

# %%
df['Monthly_Income'].sort_values(ascending=False).head(10)
# Out:
# 96315     855162.0
# 189702    844371.0
# 131385    809598.0
# 118665    802948.0
# 140476    791403.0
# 69388     783078.0
# 167381    761729.0
# 167935    758874.0
# 173776    758804.0
# 86414     758147.0
# Name: Monthly_Income, dtype: float64

# %%
(df['Monthly_Income'] > 100000).sum()
# Out:
# np.int64(4938)

# %%
(df['Monthly_Income'] > 100000).mean() * 100
# Out:
# np.float64(2.082612839826913)

# %%
sns.histplot(df['Monthly_Income'], bins = 10, kde=True)
plt.title("Income Distribution")
# Out:
# Text(0.5, 1.0, 'Income Distribution')

# %% [raw]
# The monthly income distribution is right-skewed, with most customers earning between ₹45,000 and ₹67,000. A small group of high-income customers above ₹100,000 creates a long tail in the distribution, suggesting the presence of premium customer segments.

# %% [markdown]
# ## 3. Order Amount Outliers

# %%
df['Order_Amount_INR'].describe()
# Out:
# count    237106.000000
# mean       9161.703179
# std        6681.852279
# min          50.000000
# 25%        4804.250000
# 50%        7146.000000
# 75%       11272.000000
# max       58515.000000
# Name: Order_Amount_INR, dtype: float64

# %%
df['Order_Amount_INR'].sort_values(ascending=False).head(10)
# Out:
# 66877     58515.0
# 247340    58384.0
# 103057    56280.0
# 51159     55920.0
# 4289      55596.0
# 162856    54824.0
# 16695     54556.0
# 61955     54290.0
# 28315     53872.0
# 86897     53662.0
# Name: Order_Amount_INR, dtype: float64

# %%
plt.figure(figsize=(8,5))

sns.histplot(df['Order_Amount_INR'], bins=40, kde=True)

plt.title("Order Amount Distribution")
plt.show()

# %% [raw]
# The order amount distribution is right-skewed. Most transactions fall between ₹5,000 and ₹12,000, with a median around ₹8,000. However, a significant number of high-value orders above ₹20,000 exist, indicating the presence of premium purchases.

# %% [markdown]
# ## 4. Income vs Spending Relationship

# %%
sns.scatterplot(
    x='Monthly_Income',
    y='Total_Order_INR',
    data=df,
    alpha = 0.7
)
# Out:
# <Axes: xlabel='Monthly_Income', ylabel='Total_Order_INR'>

# %% [markdown]
# ## 5. Gender vs Spending

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      151124
# Female     98876
# Name: count, dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
sns.barplot(
    x='Gender',
    y='Total_Order_INR',
    data=df
)
plt.title("Spending Distribution by Gender")
# Out:
# Text(0.5, 1.0, 'Spending Distribution by Gender')

# %%
plt.figure(figsize=(6,4))

sns.boxplot(
    x='Gender',
    y='Total_Order_INR',
    data=df
)

plt.title("Spending Distribution by Gender")
plt.show()

# %% [markdown]
# ## 6. Top CIties by Revenue

# %%
df['City'].value_counts().head(10)
# Out:
# City
# Delhi        112019
# Mumbai        15098
# Bengaluru     14013
# Hyderabad     11802
# Pune          11657
# Chennai       10346
# Ahmedabad      9474
# Jaipur         9396
# Lucknow        9383
# Kolkata        9312
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))

city_sales = df.groupby('City')['Total_Order_INR'].sum().sort_values(ascending=False)

city_sales.head(10).plot(kind='bar')

plt.title("Top 10 Cities by Revenue")
plt.ylabel("Total Revenue (INR)")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Average spending per city

# %%
city_avg = df.groupby('City')['Total_Order_INR'].mean().sort_values(ascending=False)

city_avg.head(10).plot(kind='bar', figsize=(10,5))

plt.title("Average Spending by City")
plt.ylabel("Average Order Value")
plt.show()

# %% [raw]
# The revenue analysis shows that Delhi generates significantly higher total revenue compared to other cities. This may be due to a larger customer base rather than higher spending per customer, which requires further investigation using average spending metrics.

# %% [markdown]
# ## 7. Income Group vs Spending

# %%
df['income_group'] = pd.qcut(
    df['Monthly_Income'],
    q=4,
    labels=['Low','Medium','High','Very High']
)

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x='income_group',
    y='Total_Order_INR',
    data=df
)

plt.title("Income Group vs Total Spending")
plt.show()

# %% [raw]
# The boxplot shows a clear positive relationship between income level and total spending. Customers in higher income groups tend to spend more on average, with the "Very High" income group displaying the highest median spending and largest variability.

# %% [markdown]
# ## 8. Correlation Heatmap

# %%
plt.figure(figsize=(10,6))

corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.title("Feature Correlation Matrix")
plt.show()

# %% [raw]
# The correlation analysis reveals that total customer spending is moderately influenced by monthly income, wallet balance, product order count, and individual order amount. A strong positive relationship exists between monthly income and wallet balance (0.97), while product order count shows a negative correlation with order amount (-0.57), suggesting customers purchasing more items tend to buy lower-priced products.

# %% [markdown]
# ## 9. Order Trend Over Time

# %%
#df['Date_of_order'] = pd.to_datetime(df['Date_of_order'], dayfirst=True)
df['Date_of_order'] = pd.to_datetime(
    df['Date_of_order'],
    dayfirst=True,
    errors='coerce' # converts invalid dates into NaT instead of crashing.
)

monthly_sales = df.groupby(
    df['Date_of_order'].dt.to_period('M')
)['Total_Order_INR'].sum()

plt.figure(figsize=(10,5))

monthly_sales.plot()

plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue (Millions INR)")

plt.gca().yaxis.set_major_formatter(lambda x, _: f'{x/1e6:.0f}M')

plt.show()

# %% [markdown]
# ## 10. High-Value Customer Distribution

# %%
high_value = df[df['Total_Order_INR'] > df['Total_Order_INR'].quantile(0.75)]

sns.countplot(x='City', data=high_value)
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %% [raw]
# The distribution of high-value customers shows a strong concentration in Delhi, which significantly exceeds other cities. This indicates that Delhi represents a major revenue-driving market and could be a key focus for premium marketing strategies.
